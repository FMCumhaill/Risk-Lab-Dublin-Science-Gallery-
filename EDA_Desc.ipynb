# %%
data <- read.csv(file="RISKLAB_1.3.csv", header=TRUE, sep=",")

# %%
#names(data)
#data[complete.cases(data$EVER_SMOKED), ]

data2 <- na.omit(data$HOW_MANY_YEARS_DRINKING)



#df <- rbind(data2,data$AGE) # Join A and B together.
#ggplot(data=df, aes(x=x, y=y)) + geom_point()


data2 <- paste(data$AGE,data$HOW_MANY_YEARS_DRINKING)

# %% [markdown]
# names(data)

# %%
names(data)
# Out:
#   [1] "X"
#   [2] "Timestamp"
#   [3] "ID"
#   [4] "GENDER"
#   [5] "AGE"
#   [6] "DATE_OF_BIRTH"
#   [7] "X0TIO0LITY"
#   [8] "COUNTRY_OF_RESIDENCE"
#   [9] "ENGLISH_FIRST_LENGUAGE"
#  [10] "IF_NOT_ENGLISH_SPECIFY"
#  [11] "HIGHEST_LEVEL_EDUCATION"
#  [12] "OCCUPATION"
#  [13] "DOMI0NT_HAND"
#  [14] "DO_YOU_DRIVE"
#  [15] "CURRENTLY_LEARNING_DRIVE"
#  [16] "CURRENTLY_HOLD_LEARNING_DRIVER_PERMIT"
#  [17] "CURRENTLY_HOLD_FULL_DRIVING_LICENSE"
#  [18] "RECEIVE_FULL_DRIVING_LICENSE"
#  [19] "AGE_STARTED_DRIVING"
#  [20] "AVERAGE_KM_MILEAGE_PER_YEAR"
#  [21] "HAVE_PE0LTY_POINTS"
#  [22] "PE0LTY_POINTS_FOR_WHAT"
#  [23] "COLLISIONS_LAST_TWO_YEARS"
#  [24] "HOW_MANY_COLLISIONS_LAST_TWO_YEARS"
#  [25] "HOW_SERIOUS_COLLISIONS"
#  [26] "FOR_HOW_MANY_WERE_CULPABLE"
#  [27] "EVER_SMOKED"
#  [28] "SMOKE_CURRENTLY"
#  [29] "HOW_MANY_YEARS_SMOKING"
#  [30] "HOW_MANY_CIGARETTES_PER_WEEK"
#  [31] "EVER_DRANK_ALCOHOL"
#  [32] "DRINK_CURRENTLY"
#  [33] "HOW_MANY_YEARS_DRINKING"
# ...

# %%
nrow(data2)
head(data2)

data2 <- na.omit(data2)

data.head()
# Out:
# NULL
# [1] "71 55" "68 50" "42 29" "65 47" "34 10" "34 16"
# Error in data.head(): could not find function "data.head"
# Traceback:

# %%
# Out:
#   X Timestamp     ID    GENDER AGE DATE_OF_BIRTH X0TIO0LITY
# 1 1 5/13/13 11:04 62723 Male   71  09/04/1941    American
# 2 2 5/14/13 15:20 62724 Male   68  03/07/1945    Irish
# 3 3 5/14/13 15:27 62747 Male   42  12/17/70      Irish
# 4 4 5/14/13 15:32 62722 Female 65  2/25/48       American
# 5 5 5/14/13 15:43 62746 Male   34  01/07/1979    Irish
# 6 6 5/14/13 15:57 62740 Male   34  06/07/1978    Australian
#   COUNTRY_OF_RESIDENCE ENGLISH_FIRST_LENGUAGE IF_NOT_ENGLISH_SPECIFY ...
# 1 USA                  Yes                    0                      ...
# 2 Ireland              Yes                    0                      ...
# 3 Ireland              Yes                    0                      ...
# 4 USA                  Yes                    0                      ...
# 5 Ireland              Yes                    0                      ...
# 6 England              Yes                    0                      ...
# ...

# %%
plot(data$BIS_Attention,data$AGE)
#abline(lm(log(House$price) ~ log(House$sqft_living)), col="blue") 
title("Log( Living Space & Price)")

plot(data$AGE,data$BIS_Cog_Instability)
#abline(lm(log(House$price) ~ log(House$sqft_living)), col="blue") 
title("Log( Living Space & Price)")


plot(data$AGE,data$BIS_Motor)
#abline(lm(log(House$price) ~ log(House$sqft_living)), col="blue") 
title("Log( Living Space & Price)")
plot(data$AGE,data$BIS_Perseverance)
#abline(lm(log(House$price) ~ log(House$sqft_living)), col="blue") 
title("Log( Living Space & Price)")
plot(data$AGE,data$BIS_self_control)
#abline(lm(log(House$price) ~ log(House$sqft_living)), col="blue") 
title("Log( Living Space & Price)")
plot(data$AGE,data$BIS_Cog_Complexity)
#abline(lm(log(House$price) ~ log(House$sqft_living)), col="blue") 
title("Log( Living Space & Price)")


plot(data$AGE,data$DOS_Ethical)
plot(data$AGE,data$DOS_Fin_Gambling)
plot(data$AGE,data$DOS_Fin_Investment)
plot(data$AGE,data$DOS_Fin_HealthSafety)
plot(data$AGE,data$DOS_Recreational)
plot(data$AGE,data$DOS_Social)
#summary(data)
# Out:
# Plot with title "Log( Living Space & Price)"
# Plot with title "Log( Living Space & Price)"
# Plot with title "Log( Living Space & Price)"
# Plot with title "Log( Living Space & Price)"
# Plot with title "Log( Living Space & Price)"
# Plot with title "Log( Living Space & Price)"
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title

# %%
summary(data[33])
plot(data[33])
# Out:
#  HOW_MANY_YEARS_DRINKING
#  10     :113
#  15     : 78
#  7      : 73
#  4      : 69
#  5      : 69
#  (Other):937
#  NA's   :224
# plot without title

# %%
#plot(complete.cases(data$HOW_MANY_CIGARETTES_PER_WEEK,data$DOS_Social)
#plot(data$AGE_Precent_Drinking,data$DOS_Social)


hist(complete.case(data$HOW_MANY_CIGARETTES_PER_WEEK))
# Out:
# Error in complete.case(data$HOW_MANY_CIGARETTES_PER_WEEK): could not find function "complete.case"
# Traceback:
#
# 1. hist(complete.case(data$HOW_MANY_CIGARETTES_PER_WEEK))

# %%
library(ggplot2)

A <- data.frame(x=1:5, y=11:15)
B <- data.frame(x=1:10, y=20:11)


df <- rbind(A, B) # Join A and B together.
ggplot(data=df, aes(x=x, y=y)) + geom_point()
# Out:
# plot without title
