# %%
data <- read.csv(file="Risklab_2.0.csv", header=TRUE, sep=",")
head(data)
names(data)
# Out:
#   X Timestamp     ID    GENDER AGE DATE_OF_BIRTH NATIONALITY
# 1 1 5/13/13 11:04 62723 Male   71  09/04/1941    American
# 2 2 5/14/13 15:20 62724 Male   68  03/07/1945    Irish
# 3 3 5/14/13 15:27 62747 Male   42  12/17/70      Irish
# 4 4 5/14/13 15:32 62722 Female 65  2/25/48       American
# 5 5 5/14/13 15:43 62746 Male   34  01/07/1979    Irish
# 6 6 5/14/13 15:57 62740 Male   34  06/07/1978    Australian
#   COUNTRY_OF_RESIDENCE ENGLISH_FIRST_LENGUAGE IF_NOT_ENGLISH_SPECIFY ...
# 1 USA                  Yes                    NA                     ...
# 2 Ireland              Yes                    NA                     ...
# 3 Ireland              Yes                    NA                     ...
# 4 USA                  Yes                    NA                     ...
# 5 Ireland              Yes                    NA                     ...
# 6 England              Yes                    NA                     ...
# ...

# %% [markdown]
# ## Checking distribution of BIS self control

# %%
library(psych)
describe(data$BIS_self_control)

qqnorm(data$BIS_self_control)
qqline(data$BIS_self_control)

hist(data$BIS_self_control)
boxplot(data$BIS_self_control)
# Out:
#    vars n    mean     sd       median trimmed  mad    min max range skew
# X1 1    1486 16.52423 2.826835 17     16.56134 2.9652 7   24  17    -0.1185509
#    kurtosis   se
# X1 -0.1377316 0.07333158
# Plot with title "Normal Q-Q Plot"
# Plot with title "Histogram of data$BIS_self_control"
# plot without title

# %% [markdown]
# Not prefect fit, does it really matter?
# This is outliners, but this might not be an issue going forward

# %% [markdown]
# ---

# %% [markdown]
# ## Checking distribution of car accidents

# %%
#library(psych)
#describe(data$HOW_MANY_COLLISIONS_LAST_TWO_YEARS)

#qqnorm(data$HOW_MANY_COLLISIONS_LAST_TWO_YEARS)
#qqline(data$HOW_MANY_COLLISIONS_LAST_TWO_YEARS)

#hist(data$HOW_MANY_COLLISIONS_LAST_TWO_YEARS)
#boxplot(data$HOW_MANY_COLLISIONS_LAST_TWO_YEARS)
crash <- na.omit(data$HOW_MANY_COLLISIONS_LAST_TWO_YEARS)


crash <- crash[-12]
crash <- crash[-113]

library(psych)
describe(crash)
# Out:
# Warning message in mean.default(x, na.rm = na.rm):
# "argument is not numeric or logical: returning NA"Warning message in var(if (is.vector(x) || is.factor(x)) x else as.double(x), na.rm = na.rm):
# "Calling var(x) on a factor x is deprecated and will become an error.
#   Use something like 'all(duplicated(x)[-1L])' to test for a constant vector."
# Error in median.default(x, na.rm = na.rm): need numeric data
# Traceback:
#
# 1. describe(crash)
# 2. median(x, na.rm = na.rm)
# 3. median.default(x, na.rm = na.rm)
# 4. stop("need numeric data")
