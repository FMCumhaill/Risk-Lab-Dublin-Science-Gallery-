# %%
import pandas as pd 
import seaborn as sns
data = pd.read_csv("Risklab_2.4.csv")

# %%
data.fillna(0)
# Out:
#           ID     X         Timestamp  GENDER   AGE DATE_OF_BIRTH NATIONALITY  \
# 0      63247  1238    10/14/13 10:49    Male  42.0      12/19/70       Irish
# 1      62389  1475    10/22/13 10:50  Female  24.0       5/31/88       Irish
# 2      63733  1374    10/14/13 15:39    Male  39.0       7/30/73       Irish
# 3      62450  1063  10/11/2013 10:35    Male  40.0       4/13/73       Irish
# 4      63645  1456    10/22/13 10:05    Male  32.0    04/01/1981       Irish
# 5      63718   254     5/31/13 14:05  Female  61.0       4/19/52    American
# 6      63734  1377    10/14/13 15:46    Male  33.0    11/09/1979       Irish
# 7      63818   992     8/16/13 13:42  Female  35.0       5/31/72      German
# 8      64308   661     6/26/13 10:06  Female  31.0      12/31/81   Brazilian
# 9      59225  1527    10/22/13 14:01  Female  47.0       2/25/66       Irish
# 10     62190   553     6/19/13 13:06    Male  44.0       4/19/69       Irish
# ...

# %%
data["HOW_MUCH_UNITS_OF_ALCOHOL_PER_WEEK"].fillna(0, inplace=True)
data["HOW_MUCH_UNITS_OF_ALCOHOL_PER_WEEK"]
# Out:
# 0         70
# 1         20
# 2          0
# 3         25
# 4          4
# 5         14
# 6          0
# 7          6
# 8          4
# 9          0
# 10        20
# 11         3
# 12         5
# 13         0
# 14         6
# 15        14
# 16         8
# 17         2
# 18       3.5
# 19        10
# 20        18
# 21       0.2
# 22        10
# 23         5
# 24         0
# 25         6
# 26      12.5
# 27         0
# 28         7
# 29        30
#         ...
# 1298       0
# 1299      20
# 1300       4
# 1301       0
# 1302       8
# 1303     8.5
# 1304    17.5
# 1305      12
# 1306      10
# 1307       0
# 1308       2
# 1309       0
# 1310       0
# 1311      12
# 1312      10
# 1313       3
# 1314       3
# 1315       3
# 1316     8.5
# 1317      10
# 1318       0
# 1319       3
# 1320    22.5
# 1321       8
# 1322       0
# 1323       5
# 1324      10
# 1325       6
# 1326       7
# 1327       5
# Name: HOW_MUCH_UNITS_OF_ALCOHOL_PER_WEEK, Length: 1328, dtype: object

# %%
#sns.distplot(data["HOW_MUCH_UNITS_OF_ALCOHOL_PER_WEEK"])
# Out:
# pandas.core.series.Series
